# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# !pip install gmaps

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# Use ../Weather... to go up one folder to find the correct information instead of looking for one doc. (. the folder you're in, ..the folder before)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     esperance -33.8667  121.9000     75.20        33          46
# 1        1       weyburn  49.6668 -103.8511     33.80        37          95
# 2        2     cape town -33.9258   18.4232     62.01        94          90
# 3        3  rio gallegos -51.6226  -69.2181     48.20        87           0
# 4        4      cherskiy  68.7500  161.3000    -14.01        94          63
#
#    Wind Speed Country                 Date
# 0       12.66      AU  2021-03-15 06:07:58
# 1       18.41      CA  2021-03-15 06:15:08
# 2       17.27      ZA  2021-03-15 06:05:21
# 3        5.75      AR  2021-03-15 06:09:12
# 4        5.08      RU  2021-03-15 06:08:07

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria

# %%
# Minimum temperature 75, Maximum temperature 90
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# (6.5.3)

# %%
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0         0        esperance -33.8667  121.9000     75.20        33
# 6         6         souillac -20.5167   57.5167     77.00        94
# 7         7          bubaque  11.2833  -15.8333     78.19        60
# 9         9           corowa -36.0333  146.3833     75.99        29
# 14       14          kavieng  -2.5744  150.7967     81.66        81
# 16       16          isangel -19.5500  169.2667     79.12        78
# 17       17           avarua -21.2078 -159.7750     80.60        83
# 19       19           kupang -10.1667  123.5833     86.00        79
# 20       20        busselton -33.6500  115.3333     82.00        33
# 22       22  charters towers -20.1000  146.2667     88.66        42
#
#     Cloudiness  Wind Speed Country                 Date
# 0           46       12.66      AU  2021-03-15 06:07:58
# 6           75        5.75      MU  2021-03-15 06:07:35
# ...

# %%
# 4a. Determine if there are any empty rows (null values).
# Use ".count()" to determine if there are any null values.
preferred_cities_df.count()
# Out:
# City_ID       177
# City          177
# Lat           177
# Lng           177
# Max Temp      177
# Humidity      177
# Cloudiness    177
# Wind Speed    177
# Country       176
# Date          177
# dtype: int64

# %%
# 4b. Drop any empty rows (null values) and create a new DataFrame that doesn’t have empty rows.
# Use ".dropna()" method to drop null values
clean_df=preferred_cities_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp      Lat       Lng Hotel Name
# 0         esperance      AU     75.20 -33.8667  121.9000
# 6          souillac      MU     77.00 -20.5167   57.5167
# 7           bubaque      GW     78.19  11.2833  -15.8333
# 9            corowa      AU     75.99 -36.0333  146.3833
# 14          kavieng      PG     81.66  -2.5744  150.7967
# 16          isangel      VU     79.12 -19.5500  169.2667
# 17           avarua      CK     80.60 -21.2078 -159.7750
# 19           kupang      ID     86.00 -10.1667  123.5833
# 20        busselton      AU     82.00 -33.6500  115.3333
# 22  charters towers      AU     88.66 -20.1000  146.2667

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = "Hotels"
hotel_df.head(10)

# (6.5.4)
# Out:
#                City Country  Max Temp      Lat       Lng Hotel Name
# 0         esperance      AU     75.20 -33.8667  121.9000     Hotels
# 6          souillac      MU     77.00 -20.5167   57.5167     Hotels
# 7           bubaque      GW     78.19  11.2833  -15.8333     Hotels
# 9            corowa      AU     75.99 -36.0333  146.3833     Hotels
# 14          kavieng      PG     81.66  -2.5744  150.7967     Hotels
# 16          isangel      VU     79.12 -19.5500  169.2667     Hotels
# 17           avarua      CK     80.60 -21.2078 -159.7750     Hotels
# 19           kupang      ID     86.00 -10.1667  123.5833     Hotels
# 20        busselton      AU     82.00 -33.6500  115.3333     Hotels
# 22  charters towers      AU     88.66 -20.1000  146.2667     Hotels

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    # NOTE: Can add the parameters as a dictionary of strings using the "params" keyword arguament requests.get{'base URL', params=parameteres}
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first "hotel" from the "results" and store the "name", if a hotel isn't found "skip" the city. (Use Try, Except).
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        found=hotels["results"][0]["name"]
        print(f"{found} Is Found.")
        
    except (IndexError):
        print("Hotel Is Not Found... Skipping")
    
    
    # (6.5.4)
# Out:
# Hospitality Esperance Is Found.
# Shanti Maurice Resort & Spa Is Found.
# Casa Dora, Bubaque Is Found.
# Statesman Motor Inn Is Found.
# Nusa Island Retreat Is Found.
# Volcano Sea View Tree House Is Found.
# Paradise Inn Is Found.
# Hotel On The Rock by Prasanthi Is Found.
# Observatory Guest House Is Found.
# Cattleman's Rest Motor Inn Is Found.
# Casa Tia Villa Is Found.
# Keleti Beach Resort Is Found.
# Pension Maro'i Is Found.
# Hotel El Emigrante Is Found.
# Sharif Plaza Hotel Is Found.
# Atrium Hotel Mandurah Is Found.
# Grage Hotel Bengkulu Is Found.
# Shangping Shuyuan Inn Is Found.
# Gîte kajeon Is Found.
# Pousada 100 Passos Is Found.
# Hôtel & Restaurant DIANA Ambilobe Is Found.
# ibis Styles Mt Isa Verona Is Found.
# Grand Vilia Hotel Is Found.
# 温州喜来登酒店 Is Found.
# Aldea del Bazar Hotel and Spa Is Found.
# Tour Eiffel Hotel Benin Is Found.
# Finch Bay Galapagos Hotel Is Found.
# Sunset Inn Is Found.
# Pereybere Hotel & Spa Is Found.
# Pousada Porto Praia Is Found.
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df=hotel_df.dropna() 

# EXAMPLE: if lines 7 and 13 [7, 13]
#hotel_list_df = hotel_df.drop[]

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<d1>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Max Temp} ℉</dd>
</d1>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
clean_hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. (6.5.4)

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.3)
heat_layer = gmaps.heatmap_layer(locations, dissipating=False,
            max_intensity=300, point_radius=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=clean_hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
