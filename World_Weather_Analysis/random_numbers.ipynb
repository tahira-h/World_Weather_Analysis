# %% [markdown]
# Import the random module

# %%
# Import the random module.
import random

# Import the NumPy module.
import numpy as np

# Import timeit.
import timeit

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Import Matplotlib.
import matplotlib.pyplot as plt

# %%
# Import the depencencies
import pandas as pd

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the citipy module to determine city based on latitude and longitude.
from citipy import citipy


#Import the time module.
import time

# Import the requests library. 
import requests

# Import the API key. 
from config import weather_api_key

# %%
# Type random. and after the period, press the Tab key for a list of available random module functions.

# %%
# For testing, use the randint(), random(), randrandge(), and uniform() functions.

# %%
# The randint() Function

# %%
# random. "Tab", randint
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x0000026D60AEBDA0>>

# %%
# randint is short for "random integer".
# In the 4th cell, after random. type randint(-90, 90) and "run" it

# %%
random.randint(-90, 90)
# Out:
# 82

# %%
# Results is not a decimal floating-point

# %%
# Remember, we need 1,500 random decimal numbers. 
# The random.randint() function above will only return one integer, not a floating decimal, between the given intervals.

# %%
# Try the random() Function.

# %%
# random. "Tab", random()
random.random
# Out:
# <function Random.random()>

# %%
# Using the random() function cannot get a single floating-point decimal number between 0 and 1.0.

# %%
# Add random.random() and "run" it.

# %%
random.random()
# Out:
# 0.4236702831884347

# %%
# With the results being a decimal, the random() function may help.

# %%
# The random.random() function returns only a floating-point decimal number between 0 and 1.0

# If combine random.randint(-90, 89) and random.random() to generate a floating-point decimal between -90 and 90, we can generate a random latitude.

# A change was made to the lower range of the randint() because we want numbers up to 89, when adding the floating-point decimal number, it will generate latitudes between -89.99999 and 89.99999.

# %%
# combine random.randint(-90, 89) and random.random()
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# -16.957257410064482

# %%
# Using these two functions, an algorithm can be written that will generate latitudes between -90 and 89.

# Below is a sample of what it might take to generate tend random floating-point decimal latitudes between -90 and 89.

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x+=1

# %%
# Use a similar method to get random longitudes between -180 and 180 to pair with the latitudes.

# The current code is too long.

# %%
# Try the randrange() function

# %%
# random. "Tab", randrange
random.randrange
# Out:
# <bound method Random.randrange of <random.Random object at 0x0000026D60AEBDA0>>

# %%
# The randrange() function behaves differently than the other two functions (randint() and random())

# %%
# Inside the parentheses, add two numbers, a lower and upper limit separated by a comma.

# %%
# For the randrange() function, there is an option to add a "step" parameter and set it equal to an integer. 

# This will generate increments of a given integer value, from the lowest to the upper limit.

# %%
random.randrange(-90, 90, step=1)
# Out:
# -83

# %%
# Results is a number between -90 and 90, where the step is the difference between each number in the sequence.

# %%
# Add random.randrange(-90, 90, step=3) and "run" it

# %%
random.randrange(-90, 90, step=3)
# Out:
# 63

# %%
# NOTE:
# If you do not add the step parameter, the output number will be an increment of 1, which is the default integer value.

# %%
# This function might help us by combining the random.randrange() and random.random() functions to generate a floating-point decimal between -90 and 90. 
# Similar to the combination with random.randint() and random.random()

# %%
# Try the uniform() function

# %%
# random. "Tab", uniform
random.uniform
# Out:
# <bound method Random.uniform of <random.Random object at 0x0000026D60AEBDA0>>

# %%
# The uniform function will allow us to generate a floating-point decimal number between two given numbers inside the parentheses.

# %%
# Add random.uniform(-90, 90)

# %%
random.uniform(-90, 90)
# Out:
# -25.153995833998394

# %%
# Results for the uniform() function is useful because it will return a floating-point decimal number.

# %%
# To help us generate the 1500 latitudes and longitudes

# Combine the NumPy module with one of the random module functions.

# %%
# Import the NumPy module.

# %%
# NOTE:
# The NumPy has a built-in random module, and supplements the built-in Python random module. 

# There is no need to import the random module if we import the NumPy module.

# %%
# Add np.random.uniform(-90,000, 90.000)
np.random.uniform(-90.000, 90.000)
# Out:
# 46.52981142315576

# %%
# When we use the NumPy module with the random.uniform() function, the parenthetical parameters contain a lower boundary (low value) and upper boundary (high value) that are floating point decimal numbers

# %%
# NOTE:
# Another option is to write the parameters as np.random.uniform(low=-90, high=90)

# %%
# To generate more than one floating-point decimal number between -90 and 90, we can add the "size" parameter when we use the NumPy module and set that equal to any whole number.

# %%
# Add np.random.uniform(-90.000, 90.000, size=500)
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 83.31199694,  34.69272244,  -0.09742565,  42.09934461,
#        -80.66714759, -45.42019182, -45.84509836,  58.67325058,
#        -89.04183844, -54.96632231,  20.04180737,  89.81705626,
#        -74.8654496 ,   9.81072204, -15.28681236,  45.24462631,
#        -74.02134042,  51.63015526, -48.90225458,   7.03967338,
#        -16.63574374, -28.76905154,  22.70519133,  38.3176808 ,
#         60.67558181, -86.63051807, -67.38448469, -39.38685892,
#        -71.51035587,  39.56819307, -15.61539893, -49.24819474,
#        -38.80649884, -51.39441148, -33.98052041, -13.38837677,
#        -42.53165053,   1.47018515,  60.12859859, -50.23197656,
#        -59.84097794, -52.62874147, -34.57939361,  74.35422206,
#          2.84542921,  85.67248257, -56.85196283,  -8.96774084,
#        -85.15075029,  70.37429825])

# %%
# Increase the parameter size to 1,500

# %%
# Import timeit.

# %%
# Add the %timeit magic wand before the np.random.uniform(-90.000, 90.000, size=1500)

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 21.4 µs ± 689 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# Explain:
# Above shows the amount of time it took to run this code, which is an average of 30.8 microseconds.
# The amount of time it takes to run the code depends on the processing speed and RAM of your computer.

# %%
# Run the while loop as a function

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes

# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 3.11 ms ± 65.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# NOTE:
# The np.random.uniform(-90.000, 90.000, size=1500) is faster than using the function

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.00, high=180.000, size=1500)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Add np.random.uniform(-90.000, 90.000, size=500)
np.random.uniform(-90.000, 90.000, size=500)
# Out:
# array([ 44.27423983,  55.49552298, -25.70140292,  79.59213942,
#        -33.02579758,  17.30175073,  66.35406606,  34.57358197,
#          6.59302968, -27.10486182,  13.15868947,  31.56947276,
#        -48.80810831, -23.15363894,  39.07294807, -77.92631626,
#         89.43695679,  76.82491209,  39.22944312,  56.53164035,
#         58.20210008, -55.72042562, -35.72352349, -74.24791272,
#        -30.66449903, -26.4487731 , -54.99224377,  88.32667147,
#        -35.24787361, -73.27782158, -55.74292014,  29.75509686,
#        -74.2129244 , -26.39467154, -83.96952375,  66.71194894,
#         81.12412327, -24.77207132,  17.2795708 , -72.92815426,
#        -63.56979026, -33.67967468,  69.19380944,  -8.98226371,
#         23.39046437, -67.65390807, -60.63163015, -20.32962232,
#        -18.41469292,  62.30470294,  41.27082891, -12.94159341,
#        -41.00821255, -79.18702395,  57.28371089,  57.99954324,
#         23.82183692,  15.74393255,  52.63193244,  78.46380978,
# ...

# %%
# Use the tuple() function to diplay the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# tumannyy ru
# lata sb
# samusu ws
# bur gabo so
# avarua ck
# carballo es
# usinsk ru
# korcula hr
# puerto ayora ec
# ushuaia ar
# pontes e lacerda br
# qaanaaq gl
# yellowknife ca
# mataura pf
# krasnoselkup ru
# sentyabrskiy ru
# rikitea pf
# odweyne so
# bluff nz
# surgut ru
# mujiayingzi cn
# tiksi ru
# victoria sc
# ushuaia ar
# caravelas br
# hobart au
# bredasdorp za
# nikolskoye ru
# yellowknife ca
# nizhneyansk ru
# provideniya ru
# codrington ag
# punta arenas cl
# arraial do cabo br
# mazagao br
# rikitea pf
# busselton au
# touros br
# nouadhibou mr
# esperance au
# burnie au
# barentsburg sj
# mys shmidta ru
# guadalupe y calvo mx
# port alfred za
# miranda br
# hobart au
# tuatapere nz
# coquimbo cl
# kruisfontein za
# east london za
# chokurdakh ru
# qaanaaq gl
# along in
# noumea nc
# ribeira grande pt
# butaritari ki
# kahului us
# chernyakhovsk ru
# busselton au
# cape town za
# san sebastian co
# kavieng pg
# hermanus za
# bluff nz
# ushuaia ar
# fairbanks us
# ...

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 640

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=efb435aa214d5cc0802d4cec6043c5f5

# %%
# Loop through all the cities in our list. 
for i in range(len(cities)):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list. 
for i, city in enumerate(city_data):
    
    # Group cities in sets of 50 for logging purposes:
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# %%
# Loop through all the cities in the list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes:
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
#    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
        #print(requests.get(city_url))
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]


        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list. 
        city_data.append({"City": city,
                         "Lat": city_lat,
                         "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data loading is complete. 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 13 | lata
# Processing Record 3 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 13 | avarua
# Processing Record 6 of Set 13 | carballo
# Processing Record 7 of Set 13 | usinsk
# Processing Record 8 of Set 13 | korcula
# Processing Record 9 of Set 13 | puerto ayora
# Processing Record 10 of Set 13 | ushuaia
# Processing Record 11 of Set 13 | pontes e lacerda
# Processing Record 12 of Set 13 | qaanaaq
# Processing Record 13 of Set 13 | yellowknife
# Processing Record 14 of Set 13 | mataura
# Processing Record 15 of Set 13 | krasnoselkup
# Processing Record 16 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 13 | rikitea
# Processing Record 18 of Set 13 | odweyne
# Processing Record 19 of Set 13 | bluff
# Processing Record 20 of Set 13 | surgut
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              lata  40.1629   -8.3327     51.01       100          40
# 1            avarua -21.2078 -159.7750     80.60        83          20
# 2          carballo  43.2130   -8.6910     44.01       100          90
# 3            usinsk  65.9939   57.5281     23.11        94         100
# 4           korcula  42.9622   17.1369     44.60        61          75
# 5      puerto ayora  -0.7393  -90.3518     73.99        96          65
# 6           ushuaia -54.8000  -68.3000     50.00        71          75
# 7  pontes e lacerda -15.2261  -59.3353     72.00        96         100
# 8           qaanaaq  77.4840  -69.3632     -6.02        74          99
# 9       yellowknife  62.4560 -114.3525      5.00        78          90
#
#    Wind Speed Country                 Date
# 0        2.30      PT  2021-03-15 06:13:38
# 1        2.30      CK  2021-03-15 06:08:15
# 2        2.30      ES  2021-03-15 06:17:52
# ...

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
new_column_order
# Out:
# ['City',
#  'Country',
#  'Date',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed']

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             lata  40.1629   -8.3327     51.01       100          40
# 1           avarua -21.2078 -159.7750     80.60        83          20
# 2         carballo  43.2130   -8.6910     44.01       100          90
# 3           usinsk  65.9939   57.5281     23.11        94         100
# 4          korcula  42.9622   17.1369     44.60        61          75
# ..             ...      ...       ...       ...       ...         ...
# 578  cicero dantas -10.6000  -38.3833     62.89        89          30
# 579        kamenka  51.3223   42.7678     30.00        86         100
# 580          roald  62.5833    6.1333     35.01       100          75
# 581       udachnyy  66.4167  112.4000     -3.30        81          84
# 582           surt  31.2089   16.5887     58.23        68          16
#
#      Wind Speed Country                 Date
# 0          2.30      PT  2021-03-15 06:13:38
# ...

# %%
# Add the "lats" key after the "sys" key. Continue with the 4 other keys.
lats = city_data_df
max_temps = city_data_df
humidity = city_data_df
cloudiness = city_data_df
wind_speed = city_data_df
print(lats, max_temps, humidity, cloudiness, wind_speed)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             lata  40.1629   -8.3327     51.01       100          40
# 1           avarua -21.2078 -159.7750     80.60        83          20
# 2         carballo  43.2130   -8.6910     44.01       100          90
# 3           usinsk  65.9939   57.5281     23.11        94         100
# 4          korcula  42.9622   17.1369     44.60        61          75
# ..             ...      ...       ...       ...       ...         ...
# 578  cicero dantas -10.6000  -38.3833     62.89        89          30
# 579        kamenka  51.3223   42.7678     30.00        86         100
# 580          roald  62.5833    6.1333     35.01       100          75
# 581       udachnyy  66.4167  112.4000     -3.30        81          84
# 582           surt  31.2089   16.5887     58.23        68          16
#
#      Wind Speed Country                 Date
# 0          2.30      PT  2021-03-15 06:13:38
# ...

# %%
# Extract relevant fields from the DataFrame for plotting. (6.3.1)
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# #Import the time module.
#import time

# Get today's date in seconds.
today = time.time()
today
# Out:
# 1615789295.2152717

# %%
today = time.strftime("%x")
today
# Out:
# '03/14/21'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats, 
            max_temps, 
            edgecolor="black", linewidth=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# #Buid the scatter plots for latitude and humidity.
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs CLoudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid("True")

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Generate random latitudes.

# %%
# Latitudes will be in the Northern Hemispere and positive. 

# Also, generate an equal number of random temperatures.

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Use the "lingress" function to calculate the slope, y-intercept,
# correlation coefficient (r-value), p-value, and standard deviation.

# %%
# Create Linegress
#linregress = (lats, temps)
#linregress

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err, ) = linregress(lats, temps)
#linregress(lats, temps)


#(slope, intercept, r_value, _, _) = linregress(lats, temps)

#Get the equation of the line. 
line_eq = "y = " + str(round(slope,2)) + "x+ " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x+ 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt

# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)

# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats, regress_values, "r")

# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %% [markdown]
# Find the Correlation Between Latitude and Maximum Temperature

# %%
# Using the data from the Northern and Southern Hemispheres,
# perform linear regression on all four weather parameters: 
# maximum temperature, humidity, cloudiness, and wind speed.

# %%
# The algorithm below performs the linear regression; returns the equation of 
# the regression line, and correlation coefficient, and p value; and adds the 
# regression line to a scatter plot of city weather data. Below, the code looks 
# like what has been used before.

# %% [markdown]
# Create a Linear Regression Function

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
#def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# There is no output yet, until the function is called with five parameters.

# %% [markdown]
# Create the Hemisphere DataFrames

# %%
# Add code to perform regression analysis on the maximum temperatures in the Northern and Southern Hemisperes. 

# To do this, need to create Northern Hemisphere DataFrames from the city_data_df DataFrame.

# %%
# To create a new DataFrame from a current DataFrame, use the "loc" method on the current DataFrame. 

# The loc method accesses a group of rows and columns in the current DataFrame by an index, labels, or a Boolean array. 

# The syntax to get a specific row from a current DataFrame is row = df.loc[row_index].

# %%
# Apply this method to our city_data_df DataFrame by adding the code index13 = city_data_df.loc[13]

# %%
index13 = city_data_df.loc[13]

# %%
# Return T or F

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 578    False
# 579     True
# 580     True
# 581     True
# 582     True
# Name: Lat, Length: 583, dtype: bool

# %%
# to return a DataFrame with all data fitting the criteria, for latitudes greater than or equal to 0, use the loc method on the city_data_df DataFrame.

#  Add the conditional filter city_data_df["Lat"] >= 0

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        lata  40.1629   -8.3327     51.01       100          40        2.30
# 2    carballo  43.2130   -8.6910     44.01       100          90        2.30
# 3      usinsk  65.9939   57.5281     23.11        94         100       16.75
# 4     korcula  42.9622   17.1369     44.60        61          75       10.36
# 8     qaanaaq  77.4840  -69.3632     -6.02        74          99        6.24
# ..        ...      ...       ...       ...       ...         ...         ...
# 577  cardston  49.2000 -113.3019     41.00        38           1        8.05
# 579   kamenka  51.3223   42.7678     30.00        86         100       16.82
# 580     roald  62.5833    6.1333     35.01       100          75        5.75
# 581  udachnyy  66.4167  112.4000     -3.30        81          84       13.20
# 582      surt  31.2089   16.5887     58.23        68          16       13.89
#
#     Country                 Date
# ...

# %%
# Add the head() method at the end to get the first five rows, not counting the row of column headings.

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#        City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      lata  40.1629  -8.3327     51.01       100          40        2.30
# 2  carballo  43.2130  -8.6910     44.01       100          90        2.30
# 3    usinsk  65.9939  57.5281     23.11        94         100       16.75
# 4   korcula  42.9622  17.1369     44.60        61          75       10.36
# 8   qaanaaq  77.4840 -69.3632     -6.02        74          99        6.24
#
#   Country                 Date
# 0      PT  2021-03-15 06:13:38
# 2      ES  2021-03-15 06:17:52
# 3      RU  2021-03-15 06:17:52
# 4      HR  2021-03-15 06:17:53
# 8      GL  2021-03-15 06:17:55

# %%
# Assign this DataFrame to the variable northern_hemi_df to access the data to perform linear regression.

# Take the same approach to get the cities for the Southern Hemisphere by filtering the city_data_df DataFrame for latitudes less than 0.

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %% [markdown]
# Perform Linear Regression on the Maximum Temperature for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %% [markdown]
# Perform Linear Regression on the Maximum Temperature for the Southern Hemisphere

# %%
# Call the plot_linear_regression function with the x- and y-values, and edit the title, y_label, and text_coordinates for the maximum temperature scatter plot.

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %% [markdown]
# Perform Linear Regression on the Percent Humidity for the Northern Hemisphere

# %%
# To perform the linear regression on the percent humidity for the Northern Hemisphere, set the x-value equal to the latitude column and y-value equal to the Humidity column from the northern_hemi_df DataFrame.

# %%
# Call the plot_linear_regression function with the x- and y-values, and edit the title, y_label, and text_coordinates for the percent humidity scatter plot.

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %% [markdown]
# Peform Linear Regression on the Percent Humidity for the Southern Hemisphere

# %%
# For the linear regression line and plot of the percent humidity and latitudes for the Southern Hemisphere, set the x-value equal to the latitude column and y-value equal to the humidity column from the southern_hemi_df DataFrame.

# %%
# Call the plot_linear_regression function, with the x-and y-values, and edit the title, y_label, and text_coordinates for the percent humidity scatter plot.

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n, for % Humidity', '% Humidity',(-50,15))

# %% [markdown]
# Perform Linear Regression on the Percent Cloudiness for the Northern Hemisphere

# %%
# Skill Drill

# %%
# Refactor the code we have been using for linear regression lines and plots to create the x- and y-values for the percent cloudiness and latitudes on the Northern Hemisphere DataFrame.
# Call the plot_linear_regression function with the correct arguments to create the linear regression line and plot for percent cloudiness in the Northern Hemisphere. It should look like the following plot.

# %% [markdown]
# Perform Linear Regression on the Percent Cloudiness for the Southern Hemisphere

# %%
# Generate the x-value equal to the latitude column and the y-value equal to the cloudiness column from the southern_hemi_df DataFrame. Call the plot_linear_regression function.

# Also, edit the title, y_label, and text_coordinates for the percent cloudiness scatter plot.

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n, for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Find the Correlation Between Latitude and Wind Speed

# %%
# Write an algorithm to execute the scripts to generate the x- and y-values from the Northern and Southern Hemispheres DataFrames and call the plot_linear_regression function

# %% [markdown]
# Perform Linear Regression on the Wind Speed for the Northern Hemisphere

# %%
# 1. Call the plot_linear_regression function, with the x-value equal to the Latitude column and the y-value equal to the Wind Speed column from the northern_hemi_df DataFrame.

# 2. Edit the title, y_label, and text_coordinates for the wind speed scatter plot.

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n, for Wind Speed', 'Wind Speed',(40,35))

# %% [markdown]
# Perform Linear Regression on the Wind Speed for the Southern Hemisphere

# %%
#  Call the plot_linear_regression function, with the x-value equal to the latitude column and the y-value equal to wind speed column from the southern_hemi_df DataFrame. 

#  Edit the title, y_label, and text_coordinates for the wind speed scatter plot.

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n, for Wind Speed', 'Wind Speed',(-50,35))
