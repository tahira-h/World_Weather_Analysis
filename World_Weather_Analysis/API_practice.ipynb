# %%
# Import citipy
from citipy import citipy

# Import the requests library. 
import requests

# Import the API key. 
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the depencencies
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
# Import Matplotlib.
#import matplotlib.pyplot as plt

#Import the time module.
import time

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Display the coordinate pairs

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Unpack our lat_lngs zip object into a list. 

# Doing this, we need to create a set of random latitudes and longitudes on.

# %%
# Create a for loop

# %%
# Use the tuple() function to diplay the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         citypy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 0

# %% [markdown]
# Make an API Call

# %%
# Before making an API call for the OpenWeatherMap, use the url provided on the OpenWeatherMap website.

# %%
# Practice making an API call and look at the data returned from the API call.

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=efb435aa214d5cc0802d4cec6043c5f5

# %%
# Results is an added feature to the URL: units=Imperial
# There are 3 unit options: standard, metric, and imperial.

# %%
# NOTE: Click the url in the output and a new window will open in a default web browser.

# %% [markdown]
# Add a city to the URL to get the current weather data. (Making an API Call)

# %%
# Reminder:
# 1. We are creating a string to get the weather data for Boston by using the city_url.

# 2. To create the city_url we add the parameter, &q= and "Boston" to the url.

# %%
# Create an endpoint URL for a city. 
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=efb435aa214d5cc0802d4cec6043c5f5&q=Boston

# %%
# Results?
# Click on the URL, a new window will open showing the current weather for Boston.

# %%
# Add the JSONView extension to your Chrome web browser?

# %% [markdown]
# Retrieve a Response Using the get() Method

# %%
# Use the get() method, a feature of Requests Librarary. to request data from an API.

# %%
# NOTE: The get() method is one of many HTTP methods that allows us to access, add, delete, get the headers, and perform other actions on the request.

# %%
# Inside the parentheses of the get() method, add the URL "city_url"

# This will make a request to get weather data from Boston.

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# NOTE:
# If trying to get weather data from an unrecognized city, or if the weather data for a city isn't available, you would get a 404 resonse.

# %%
# What would happen if a city name is misspelled - "Bston" instead of "Boston" ?

# %%
# Create a endpoint URL for a city. 
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %% [markdown]
# Get Data from a Response

# %%
# What happens if a city name is spelled correctly and we get a valid response?

# %%
# Create an endpoint URL for a city. 
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# There is valid response from the server, now decide on the data format. 

# Data format options:
# text, JSON, XML, or HTML format. 

# Apply one of these attributes to get the data into a useful format to parse.

# %%
# One format that provides a preview of the JSON data is the "text" attribute.

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}],"base":"stations","main":{"temp":20.61,"feels_like":-0.06,"temp_min":19,"temp_max":21.99,"pressure":1019,"humidity":35},"visibility":10000,"wind":{"speed":25.32,"deg":320,"gust":36.82},"clouds":{"all":20},"dt":1615788307,"sys":{"type":1,"id":3486,"country":"US","sunrise":1615805751,"sunset":1615848625},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the "JSON" text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 20.61,
#   'feels_like': -0.06,
#   'temp_min': 19,
#   'temp_max': 21.99,
#   'pressure': 1019,
#   'humidity': 35},
#  'visibility': 10000,
#  'wind': {'speed': 25.32, 'deg': 320, 'gust': 36.82},
#  'clouds': {'all': 20},
#  'dt': 1615788307,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1615805751,
#   'sunset': 1615848625},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# Handle Request Errors

# %%
# When submitting a get request for the city_weather, the valid response wanted is "200" before we retrieve any data.

# %%
# To check if the response is valid, write a conditional expression that will evaluate whether the status code is "200".

# If the response says the data was not found, a response other than 200 such as 400, we can print out a statement that says the weather was not found.

# %%
# Create an endpoint URL for a city. 
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather Found.")
else: 
    print(f"City Weather Not Found")
# Out:
# City Weather Found.

# %%
# NOTE:
# If the status_code is something other than 200, JSON will be returned in the requests.

# Can determine if the response is successful by checking the status_code, clicking the URL, or retrieving specific information from the JSON file.

# %%
# Test if we get the JSON formatted data "below".

# %%
# Create an endpoint URl for a city. 
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather Found.")
else:
    print(f"City Weather Not Found.")
# Out:
# City Weather Found.

# %%
# If we type print(city_url) the output is a url, but click on the web browser there is no data to retrieve (404 response).

# %%
# Create an endpoint URl for a city. 
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=efb435aa214d5cc0802d4cec6043c5f5&q=Bston

# %% [markdown]
# Parse a Response from an API

# %%
# For each city in our lats_lngs list, need to retrieve the following data and add it to a DataFrame:

# - City, country, and date
# - Latitude and longitude
# - Maximum temperature
# - Humidity
# - Cloudiness
# - Wind speed

# %%
# The above information will allow collection of weather data from more than 500 cities.

# %%
# First, correct the spelling for the city "Boston" to get a valid url.

# %%
# Create an endpoint URL for a city. 
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 20.61,
#   'feels_like': -0.06,
#   'temp_min': 19,
#   'temp_max': 21.99,
#   'pressure': 1019,
#   'humidity': 35},
#  'visibility': 10000,
#  'wind': {'speed': 25.32, 'deg': 320, 'gust': 36.82},
#  'clouds': {'all': 20},
#  'dt': 1615788307,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1615805751,
#   'sunset': 1615848625},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get something simple, like the country coude from the JSON formatted data above, which is in a nested dictionary where the first dictionary starts with "sys"

# %%
# Assign a variable to the city_weather.json() data to the variable "boston_data"

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
# Using the "sys" key to get the corresponding value, type boston_data['sys']
boston_data["sys"]
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1615805751,
#  'sunset': 1615848625}

# %%
# Add the "country" key in the brackets after the "sys" key.
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
# When used boston_data["sys"] above, there was a key for sunrise and a key for sunset in the output. 
# The values for these keys is the time of day in seconds in a database timestamp format.

# %%
# To retrieve the data in the weather data, add the "dt" key to the boston_data variable
boston_data["dt"]
# Out:
# 1615788307

# %%
# Use similar syntax to get the time of day, to get latitude, longitude, maximum temperature, humidity, percent cloudiness, and windspeed below.
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 21.99 35 20 25.32

# %% [markdown]
# Convert the Date Timestamp

# %%
boston_data["dt"]
# Out:
# 1615788307

# %%
# The format above is called Coordinated Universal Time(UTC) or Greenwich Mean Time(GMT).

# %%
# To convert the timestamp to the International Organization for Standardization (ISO) format,
# or YYYY-MM-DD-HH-MM-SS, use the Python datetime module.

# %%
# Convert the date from Boston weather data in the JSON format to the ISO format.

# %%
# Import the datetime module from the datetime library.

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date formate with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 3, 15, 6, 5, 7)

# %%
# We can convert this datetime format to year-month-day hours:minutes:seconds using 
# the Python string format method strftime() and adding how we want the string
# to look in parenthesis.

# strftime('%Y-%m-%d %H:%M:%S')

# %%
# Add .strftime('%Y-%m-%d %H:%M:%S') to end the conversion:

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-03-15 06:05:07'

# %%
# Go to WeatherPy.ipynb file to Import Dependencies, and Initialize an Empty List and Counters

# %%
# Back from WeatherPy.ipynb

# %% [markdown]
# Create Longitude and Latitude Combinations

# %%
# Import the Pandas, Matplotlib, and NumPy dependencies

# %%
# To ensure enough latitudes and longitudes, start with 1,500.

# Pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them
# lat_lngs with the zip() function

# %%
# Practice zipping a small number of latitudes and longitudes and then unpacking the unzipped tuple to see how the packing and unpacking work.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.00, high=180.000, size=1500)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(lat_lngs)

# %% [markdown]
# Import Dependencies, and Initialize an Empty List and Counters

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Add np.random.uniform(-90.000, 90.000, size=500)
np.random.uniform(-90.000, 90.000, size=500)
# Out:
# array([ 23.31593419,  54.12849929,  13.25641426,  -0.32460812,
#         77.5375709 ,   7.27756251,  -9.39739369,  83.64515272,
#        -20.68091266,  19.81801608,  82.70446464,  40.58046525,
#         34.68891901,  35.61634488,  87.61277506,  76.59696869,
#        -66.31268516, -51.9754391 ,  46.2846004 , -87.21398235,
#         72.29399552,   0.84046784, -29.20849971, -16.52196441,
#         43.92510245, -61.06993912,  87.34733308,  37.19740745,
#         -7.59581967,  41.62851204, -72.80763395,  73.50328119,
#         64.01621344, -31.68389954,  62.24705584, -36.06797343,
#        -59.3340829 ,  49.84670331,  27.70444412, -58.81315226,
#         77.25009996, -83.63105694,  -4.56180139, -71.73036145,
#        -62.46116007,   8.60312687,  19.09303549, -11.40713599,
#        -89.09376109,  48.54511315, -80.13953739, -18.89587047,
#         -1.04271991, -35.41495229,  -8.82681035, -88.9717955 ,
#         18.35108795,  53.99372465, -86.34291912,  -3.70597681,
# ...

# %%
# Import the citipy script

# %%
# Use the tuple() function to diplay the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# rikitea pf
# longyearbyen sj
# bengkulu id
# port elizabeth za
# taolanaro mg
# atuona pf
# college us
# vardo no
# jamestown sh
# curup id
# jamestown sh
# tasiilaq gl
# upernavik gl
# rikitea pf
# amderma ru
# talnakh ru
# cheremshan ru
# anqing cn
# rikitea pf
# ayan ru
# hihifo to
# gushikawa jp
# dayong cn
# souillac mu
# atuona pf
# esperance au
# rikitea pf
# mar del plata ar
# khatanga ru
# illoqqortoormiut gl
# maputo mz
# chuy uy
# hobart au
# souillac mu
# puerto ayora ec
# kavieng pg
# saint-augustin ca
# longyearbyen sj
# srandakan id
# albany au
# poum nc
# taolanaro mg
# mengcheng cn
# mataura pf
# bluff nz
# soyo ao
# bihoro jp
# faanui pf
# viedma ar
# port-gentil ga
# severo-kurilsk ru
# saldanha za
# rikitea pf
# hit iq
# vaini to
# ponta do sol cv
# ushuaia ar
# vao nc
# phan rang vn
# darhan mn
# cape town za
# mataura pf
# punta arenas cl
# lavrentiya ru
# barrow us
# punta arenas cl
# raymondville us
# atuona pf
# vaini to
# kapaa us
# kahului us
# ...

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=efb435aa214d5cc0802d4cec6043c5f5

# %% [markdown]
# Loop Through the List of Cities and Build the City URL.

# %%
# Iterate through the list of and begin building the URL for the city,
# while grouping our records in sets of 50.

# Use for i in range(len(cities)) and the index tells us when we get back to 50.

# Can also retrieve the city from the cities list and add the city_url by using indexing.

# %%
# Loop through all the cities in our list. 
for i in range(len(cities)):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# The enumerate() method is    "for i, item in enumerate(list):"

# %%
# Loop through all the cities in the list. 
for i, city in enumerate(city_data):
    
    # Group cities in sets of 50 for logging purposes:
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# %% [markdown]
# Handle API Request Errors with try-except Blocks

# %%
# Handling errors while parsing weather data from a JSON file.

# %%
# Add a "try-except" block to our code to prevent the API request from stopping prematurely if the "city_weather" request isn't a valid response

# %%
# If the request isn't valid, the code will not find the first item (New  York) which is in the dictionary "coord" with code 'city_lat = city_weather["coord"]["lat"], and skip the city (New  York) and continue to run'

# %%
# try-except block

# try:
#   Do something
# except:
#   print("An exception occured")

# %%
# Add a try block by doing the following:

# 1. Parse the JSON file
# 2. Assign variables for each piece of data we need.
# 3. Add the data to the cities list in a dictionary format.

# %%
# Add the try-except block after "record_count += 1"... This is where the orignal code ended before the error.

# %%
# Loop through all the cities in the list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes:
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
#    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
        #print(requests.get(city_url))
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]


        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list. 
        city_data.append({"City": city,
                         "Lat": city_lat,
                         "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data loading is complete. 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | rikitea
# Processing Record 2 of Set 13 | longyearbyen
# Processing Record 3 of Set 13 | bengkulu
# Processing Record 4 of Set 13 | port elizabeth
# Processing Record 5 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 13 | atuona
# Processing Record 7 of Set 13 | college
# Processing Record 8 of Set 13 | vardo
# Processing Record 9 of Set 13 | jamestown
# Processing Record 10 of Set 13 | curup
# Processing Record 11 of Set 13 | tasiilaq
# Processing Record 12 of Set 13 | upernavik
# Processing Record 13 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 13 | talnakh
# Processing Record 15 of Set 13 | cheremshan
# Processing Record 16 of Set 13 | anqing
# Processing Record 17 of Set 13 | ayan
# Processing Record 18 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 13 | gushikawa
# Processing Record 20 of Set 13 | dayong
# Processing Record 21 of Set 13 | souillac
# ...

# %% [markdown]
# Create a DataFrame of City Weather Data

# %%
# Reminder
# To convert a list of dictionaries to a Pandas DataFrame, use df = pd.DataFrame(list with dictionaries)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         rikitea -23.1203 -134.9692     80.15        77          72
# 1    longyearbyen  78.2186   15.6401     -2.20        65          75
# 2        bengkulu  -3.8004  102.2655     85.71        65          18
# 3  port elizabeth -33.9180   25.5701     68.00       100          40
# 4          atuona  -9.8000 -139.0333     80.15        69           7
# 5         college  64.8569 -147.8028      0.00        77          20
# 6           vardo  70.3705   31.1107     28.40        93          75
# 7       jamestown  42.0970  -79.2353     21.00        63           1
# 8           curup  -3.4667  102.5333     78.85        85          67
# 9        tasiilaq  65.6145  -37.6368     26.60        59          75
#
#    Wind Speed Country                 Date
# 0        7.36      PF  2021-03-15 06:07:46
# 1       11.50      SJ  2021-03-15 06:08:04
# 2        6.22      ID  2021-03-15 06:08:34
# ...
